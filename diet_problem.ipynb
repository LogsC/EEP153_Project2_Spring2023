# %%
# Returns the minimum nutrition quantities of different nutrients for a given age and sex
# age: age of person, int
# sex: sex of person ("M" or "F"), str

# !!! data only for minimum requirements. not sure how to implement for recommended values
def RDA(age,sex):
    RDIs = read_sheets('https://docs.google.com/spreadsheets/d/1y95IsQ4HKspPW3HHDtH7QMtlDA66IUsCHJLutVL-MMc/');
    bmin = RDIs['diet_minimums'].set_index('Nutrition').drop('Source',axis=1)
    
    col = "";
    if not(sex=="M" or sex=="F"): return "Sex must be 'M' or 'F'";
    if age<1: return "Input an age >= 1";
    if age<=3: col = "C 1-3";
    elif age<=8: col = sex+" 4-8";
    elif age<=13: col = sex+" 9-13";
    elif age<=18: col = sex+" 14-18";
    elif age<=30: col = sex+" 19-30";
    elif age<=50: col = sex+" 31-50";
    else: col = sex+" 51+";

    return bmin[col];

# %% [markdown]
# ## Introduction

# %% [markdown]
# We&rsquo;re thinking about the problem of finding the cheapest possible
# nutritious diet.  Last time we argued that this problem could be
# expressed as a *linear program*
# $$
#     \min_x p'x
# $$
#
# such that
# $$\begin{bmatrix}
#       A\\
#       -A
#    \end{bmatrix}x \geq \begin{bmatrix}
#                         b_{min}\\
#                         -b_{max}
#                       \end{bmatrix},$$
#
# where $p$ is a vector of prices, $A$ is a matrix that maps
# vectors of quantities of food into vectors of nutrients, and where
# $b_{min}$ and $b_{max}$ are respectively dietary minimums
# and maximums of different nutrients.  As above, we will sometimes stack these
# objects, obtaining
# $$
#       \tilde{A} = \begin{bmatrix}
#                         A_{min}\\
#                         -A_{max}
#                       \end{bmatrix}
#   $$
# and
# $$
#       \tilde{b} = \begin{bmatrix}
#                         b_{min}\\
#                         -b_{max}
#                       \end{bmatrix}
#   $$
#
# Our job in this notebook: Specify the objects required by the linear
# program $(p,\tilde{A},\tilde{b})$, then have the computer solve the problem for us.

# %% [markdown]
# ## USDA Food Central DataBase

# %% [markdown]
# The USDA maintains a database of nutritional information, where
# different kinds of food are identified by an FDC number.  They do
# not provide any data on prices.
#
# To look up nutritional information, use api provided by the USDA at
# [https://fdc.nal.usda.gov/](https://fdc.nal.usda.gov/).   You should sign up for a
# free api key (see directions on page), then add that key here in
# place of &ldquo;DEMO<sub>KEY</sub>&rdquo;.

# %%
apikey = "DEMO_KEY"  # Replace with a real key!  "DEMO_KEY" will be slow...

# %% [markdown]
# ### Looking up foods

# %% [markdown]
# I&rsquo;ve written a little module `fooddatacentral`.  Install it (only once!), along with other requirements.

# %%
#%pip install -r requirements.txt --upgrade
# Out:
# Requirement already satisfied: pint>=0.18 in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.20.1)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.28.2)
# Requirement already satisfied: python-gnupg in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: eep153_tools in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.11)
# Requirement already satisfied: fooddatacentral in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (1.26.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This module offers some simple methods
#
# -   `search`
# -   `nutrients`
# -   `units`

# %% [markdown]
# ### FDC Search

# %% [markdown]
# Here&rsquo;s a little code to help look up FDC codes for foods of
# different descriptions.

# %%
import fooddatacentral as fdc

fdc.search(apikey,"marmite")
# Out:
#      fdcId           description commonNames    additionalDescriptions  \
# 0  2345533  Yeast extract spread              Marmite;Vegemite;Promite
# 1  1857448         YEAST EXTRACT         NaN                       NaN
#
#          dataType    foodCode publishedDate                  foodCategory  \
# 0  Survey (FNDDS)  75236500.0    2022-10-28  Mustard and other condiments
# 1         Branded         NaN    2021-07-29   Baking Additives & Extracts
#
#    foodCategoryId                                 allHighlightFields  ...  \
# 0       2650737.0  <b>Includes</b>: <em>Marmite</em>;Vegemite;Pro...  ...
# 1             NaN                                                     ...
#
#                        brandOwner brandName  \
# 0                             NaN       NaN
# 1  Graham Packaging Company, L.P.   MARMITE
#
#                                          ingredients  marketCountry  \
# 0                                                NaN            NaN
# 1  YEAST EXTRACT, SALT, CARROT AND ONION EXTRACTS...  United States
#
#   modifiedDate dataSource packageWeight servingSizeUnit servingSize  \
# 0          NaN        NaN           NaN             NaN         NaN
# 1   2017-07-14         LI  4.4 oz/125 g               g         4.0
#
#         tradeChannels
# 0                 NaN
# 1  [NO_TRADE_CHANNEL]
#
# [2 rows x 29 columns]

# %% [markdown]
# ### FDC Nutrients

# %% [markdown]
# Once we know the `fdc_id` of a particular food we can look up a
# variety of information on it.  We start with nutrients

# %%
id = 2345533    # Put an FDC ID HERE!
fdc.nutrients(apikey,fdc_id=id)
# Out:
#                                     Quantity Units
# Protein                                 23.9     g
# Total lipid (fat)                        0.9     g
# Carbohydrate, by difference             20.4     g
# Energy                                 185.0  kcal
# Alcohol, ethyl                           0.0     g
# ...                                      ...   ...
# PUFA 20:5 n-3 (EPA)                      0.0     g
# MUFA 22:1                                0.0     g
# PUFA 22:5 n-3 (DPA)                      0.0     g
# Fatty acids, total monounsaturated       0.0     g
# Fatty acids, total polyunsaturated       0.0     g
#
# [65 rows x 2 columns]

# %% [markdown]
# ### FDC Ingredients

# %% [markdown]
# We can also look up the ingredients for many foods in the FDC:

# %%
fdc.ingredients(apikey,id)
# Out:
#              Ingredient  Food Code/NDB Number  Weight (grams)
# 0  Yeast extract spread                 43406             100

# %% [markdown]
# ## Prices

# %% [markdown]
# Now, let&rsquo;s begin thinking about constructing the objects we need for
# the linear program.  Start with specifying $p$, the vector of prices.
#
# Also note that some kinds of foods need to have unit weights (in
# grams) supplied under &ldquo;Units&rdquo;; e.g., extra large eggs are taken to
# each weigh 56g.  These conversions can also often be found on the USDA
# FDC website.
#
# Food is purchased in particular units (gallons, pounds, grams).  And
# in some cases the natural units are things like donuts or eggs, in
# which case we may need to define our  own units (see the example of
# &ldquo;xl<sub>egg</sub>&rdquo; below).  New units can be added to the file [file:///home/ligon/.unitsrc](file:///home/ligon/.unitsrc).

# %% [markdown]
# ### Example: Stigler&rsquo;s Foods

# %% [markdown]
# In his 1945 paper George Stigler constructed a subsistence diet
# chosen from 14 different goods (see Table B in [Stigler 1945](https://www.jstor.org/stable/pdf/1231810.pdf)), with
# prices reported for the years 1939 & 1944.
#
# I&rsquo;ve looked up more recent prices for these same goods, and recorded
# these at
# [https://docs.google.com/spreadsheets/d/1ObK5N_5aVXzVHE7ZXWBg0kQvPS3k1enRwsUjhytwh5A/](https://docs.google.com/spreadsheets/d/1ObK5N_5aVXzVHE7ZXWBg0kQvPS3k1enRwsUjhytwh5A/), in a sheet called &ldquo;Stigler Table B (2022 Prices)&rdquo;
#
# The code below allows us to collect data on different kinds of food
# with their prices from google spreadsheets.
#
# In this case, we use a function from a module I&rsquo;ve written,
#  `eep153_tools.sheets`, to read the price data for the
# Stigler goods.

# %%
import pandas as pd
from eep153_tools.sheets import read_sheets

df = read_sheets("1ObK5N_5aVXzVHE7ZXWBg0kQvPS3k1enRwsUjhytwh5A",sheet='Stigler Table B (2022 Prices)')

df = df.set_index('Food')

df
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
#                  Quantity   Units  Price         Date Location      FDC
# Food
# Wheat Flour          80.0      oz   3.79  [2022-2-28]  Safeway   390092
# Wheat Cereal         16.4      oz   3.49  [2022-2-28]  Safeway   391549
# Corn Meal            80.0      oz   4.49  [2022-2-28]  Safeway   363629
# Rolled Oats          42.0      oz   3.99  [2022-2-28]  Safeway   734348
# Evaporated Milk      12.0      oz   1.99  [2022-2-28]  Safeway   648546
# Cabbage               1.0     lbs   1.29  [2022-2-28]  Safeway   169975
# Potatoes              1.0     lbs   1.49  [2022-2-28]  Safeway   576920
# Spinach               1.0      oz   0.25  [2022-2-28]  Safeway   168462
# Sweet Potatoes        1.0     lbs   1.99  [2022-2-28]  Safeway   600987
# Navy Beans            1.0     lbs   3.49  [2022-2-28]  Safeway   535776
# Sugar                 4.0     lbs   3.79  [2022-2-28]  Safeway   169656
# Beets                 1.0     lbs   1.29  [2022-2-28]  Safeway   169145
# Milk (Whole)          1.0  gallon   5.29  [2022-2-28]  Safeway  1111480
# Liver (Beef)          1.0     lbs   5.99  [2022-2-28]  Safeway   169451

# %% [markdown]
# ### Example: My Shopping Trip

# %% [markdown]
# Here&rsquo;s an example of describing some different kinds of food, along with
# data on food prices.  This is all just based on a trip I took to the
# grocery store, except that I&rsquo;ve used the USDA database to look up FDC
# numbers.  Note that we may need extra information to map some units
# into weights.  For example, I still need to weigh a crumpet.

# %% [markdown]
# #### Trip to Monterey Market

# %%
import pandas as pd
from eep153_tools.sheets import read_sheets

df = read_sheets('https://docs.google.com/spreadsheets/d/1ObK5N_5aVXzVHE7ZXWBg0kQvPS3k1enRwsUjhytwh5A/',sheet="Ligon's Shopping Trip")

df = df.set_index('Food')

df
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
#                         Quantity    Units  Price              Date  \
# Food
# Milk, 2% fat                1.00   gallon   4.99  [2019-09-14 Sat]
# Eggs, extra large          12.00   xl_egg   3.59  [2019-09-14 Sat]
# Crumpets                    6.00  crumpet   3.19  [2019-09-14 Sat]
# Bananas                     1.00    pound   3.15  [2019-09-14 Sat]
# Carrots, Organic            2.00    pound   2.29  [2019-09-14 Sat]
# Cauliflower                 2.51    pound   4.24  [2019-09-14 Sat]
# Endive, Red                 1.26    pound   6.27  [2019-09-14 Sat]
# Figs, black mission         1.00    pound   4.98  [2019-09-14 Sat]
# Leeks, Organic              1.00    pound   1.29  [2019-09-14 Sat]
# Lettuce, Little Gem         1.00    pound   5.98  [2019-09-14 Sat]
# Mushrooms, King Oyster      1.00    pound  12.00  [2019-09-14 Sat]
# Onion, yellow               1.00    pound   0.39  [2019-09-14 Sat]
# Orange juice                0.50   gallon   8.98  [2019-09-14 Sat]
# Parsnip                     1.00    pound   1.98  [2019-09-14 Sat]
# Potato, marble mix          1.00    pound   2.59  [2019-09-14 Sat]
# Rhubarb                     1.00    pound   1.84  [2019-09-14 Sat]
# Potato, russet             10.00    pound   2.98  [2019-09-14 Sat]
# Squash, Zucchini            1.00    pound   1.49  [2019-09-14 Sat]
# Marmite                     4.40       oz  11.99  [2019-09-14 Sat]
# Beef Liver                  1.00    pound   9.56  [2019-09-14 Sat]
#
#                                          Location      FDC
# Food
# Milk, 2% fat            Monterey Market, Berkeley  2485214
# Eggs, extra large       Monterey Market, Berkeley   747997
# Crumpets                Monterey Market, Berkeley  1930285
# Bananas                 Monterey Market, Berkeley   173944
# Carrots, Organic        Monterey Market, Berkeley   170393
# Cauliflower             Monterey Market, Berkeley   169986
# Endive, Red             Monterey Market, Berkeley   168412
# Figs, black mission     Monterey Market, Berkeley   438223
# Leeks, Organic          Monterey Market, Berkeley   169246
# Lettuce, Little Gem     Monterey Market, Berkeley  2372577
# Mushrooms, King Oyster  Monterey Market, Berkeley  2003599
# Onion, yellow           Monterey Market, Berkeley   170000
# Orange juice            Monterey Market, Berkeley  2073024
# Parsnip                 Monterey Market, Berkeley   170417
# Potato, marble mix      Monterey Market, Berkeley   170032
# Rhubarb                 Monterey Market, Berkeley   167758
# Potato, russet          Monterey Market, Berkeley   170030
# Squash, Zucchini        Monterey Market, Berkeley   169291
# Marmite                 Monterey Market, Berkeley  2345533
# Beef Liver              Monterey Market, Berkeley  2341562

# %% [markdown]
# ### Units & Prices

# %% [markdown]
# Now, the prices we observe can be for lots of different quantities and
#  units.  The FDC database basically wants everything in either hundreds
#  of grams (hectograms) or hundreds of milliliters (deciliters).
#
# Sometimes this conversion is simple; if the price we observe is for
# something that weighs two kilograms, that&rsquo;s just 20 hectograms.
# Different systems of weights and volumes are also easy; a five pound
# bag of flour is approximately 22.68 hectograms.
#
# Othertimes things are more complicated.  If you observe the price of a
# dozen donuts, that needs to be converted to hectograms, for example.
#
# A function `units` in the [fdc](fooddatacentral.py) module accomplishes this conversion
# for many different units, using the `python` [pint module](https://pint.readthedocs.io/en/latest/).  A file
# [~/.units.rc](Data/food_units.txt) can be edited to deal with odd cases such as
# donuts, using a format described in the `pint` [documentation](https://pint.readthedocs.io/en/latest/advanced/defining.html).
#
# Here&rsquo;s an example of the usage of `fooddatacentral.units`:

# %%
# Try your own quantities and units.
# If units are missing try adding to ~/.unitsrc

print(fdc.units(5,'lbs'))
print(fdc.units(1,'gallon'))
print(fdc.units(2,'tea_bag'))
print(fdc.units(12,'donut'))
# Out:
# 22.679618500000004 hectogram
# 37.85411783999999 deciliter
# 0.06 hectogram
# 4.4225256075 hectogram

# %% [markdown]
# Now, use the `units` function to convert all foods to either
#  deciliters or hectograms, to match FDC database:

# %%
import fooddatacentral as fdc

# Convert food quantities to FDC units
df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))

# Now divide price by the FDC Quantity to get, e.g., price per hectoliter
df['FDC Price'] = df['Price']/df['FDC Quantity']

df.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
Prices = df.groupby('Food')['FDC Price'].min()

Prices
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1990: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# Food
# Bananas                    0.6944561258823643 / hectogram
# Beef Liver                 2.1076192264874294 / hectogram
# Carrots, Organic           0.2524292902016848 / hectogram
# Cauliflower               0.37241433930831913 / hectogram
# Crumpets                                 nan / milliliter
# Eggs, extra large          0.5342261904761904 / hectogram
# Endive, Red                1.0970622094437954 / hectogram
# Figs, black mission        1.0979020656806904 / hectogram
# Leeks, Organic            0.28439631821849204 / hectogram
# Lettuce, Little Gem         1.318364327865568 / hectogram
# Marmite                      9.61215463126066 / hectogram
# Milk, 2% fat               0.1318218541267161 / deciliter
# Mushrooms, King Oyster     2.6455471462185307 / hectogram
# Onion, yellow             0.08598028225210225 / hectogram
# Orange juice              0.47445300603523477 / deciliter
# Parsnip                   0.43651527912605753 / hectogram
# Potato, marble mix         0.5709972590588328 / hectogram
# Potato, russet            0.06569775413109351 / hectogram
# Rhubarb                    0.4056505624201747 / hectogram
# Squash, Zucchini          0.32848877065546755 / hectogram
# Name: FDC Price, dtype: object

# %% [markdown]
# ## Mapping to Nutrients

# %% [markdown]
# Next we want to build the matrix $A$, which maps quantities of food
#  into nutrients.  We have a list of foods with prices.  Do lookups on USDA database
#  to get nutritional information.

# %%
import warnings

D = {}
count = 0
for food in  df.index:
    try:
        FDC = df.loc[df.index==food,:].FDC.values[0]
        count+=1
        D[food] = fdc.nutrients(apikey,FDC).Quantity
        print(food)
    except AttributeError:
        warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")

D = pd.DataFrame(D,dtype=float)

D
# Out:
# Milk, 2% fat
# Eggs, extra large
# Crumpets
# Bananas
# Carrots, Organic
# Cauliflower
# Endive, Red
# Figs, black mission
# Leeks, Organic
# Lettuce, Little Gem
# Mushrooms, King Oyster
# Onion, yellow
# Orange juice
# Parsnip
# Potato, marble mix
# Rhubarb
# Potato, russet
# Squash, Zucchini
# Marmite
# Beef Liver
#                                Milk, 2% fat  Eggs, extra large  Crumpets  \
#  Ergosta-5,7-dienol                     NaN                NaN       NaN
#  Ergosta-7,22-dienol                    NaN                NaN       NaN
# Alanine                                 NaN              0.714       NaN
# Alcohol, ethyl                          NaN                NaN       NaN
# Amino acids                             NaN              0.000       NaN
# ...                                     ...                ...       ...
# Vitamin K (Menaquinone-4)               NaN                NaN       NaN
# Vitamin K (phylloquinone)               NaN                NaN       NaN
# Vitamins and Other Components           NaN              0.000       NaN
# Water                                   NaN             86.300       NaN
# Zinc, Zn                                NaN                NaN       NaN
#
#                                Bananas  Carrots, Organic  Cauliflower  \
#  Ergosta-5,7-dienol                NaN               NaN          NaN
#  Ergosta-7,22-dienol               NaN               NaN          NaN
# Alanine                           0.04             0.113        0.116
# Alcohol, ethyl                    0.00             0.000        0.000
# Amino acids                       0.00             0.000        0.000
# ...                                ...               ...          ...
# Vitamin K (Menaquinone-4)          NaN               NaN        0.000
# Vitamin K (phylloquinone)         0.50            13.200       15.500
# Vitamins and Other Components     0.00             0.000        0.000
# Water                            74.91            88.290       92.070
# Zinc, Zn                          0.15             0.240        0.270
#
#                                Endive, Red  Figs, black mission  \
#  Ergosta-5,7-dienol                    NaN                  NaN
#  Ergosta-7,22-dienol                   NaN                  NaN
# Alanine                              0.062                  NaN
# Alcohol, ethyl                       0.000                  NaN
# Amino acids                          0.000                  NaN
# ...                                    ...                  ...
# Vitamin K (Menaquinone-4)              NaN                  NaN
# Vitamin K (phylloquinone)          231.000                  NaN
# Vitamins and Other Components        0.000                  NaN
# Water                               93.790                  NaN
# Zinc, Zn                             0.790                  NaN
#
#                                Leeks, Organic  Lettuce, Little Gem  \
#  Ergosta-5,7-dienol                       NaN                  NaN
#  Ergosta-7,22-dienol                      NaN                  NaN
# Alanine                                 0.074                  NaN
# Alcohol, ethyl                          0.000                  NaN
# Amino acids                             0.000                  NaN
# ...                                       ...                  ...
# Vitamin K (Menaquinone-4)                 NaN                  NaN
# Vitamin K (phylloquinone)              47.000                  NaN
# Vitamins and Other Components           0.000                  NaN
# Water                                  83.000                  NaN
# Zinc, Zn                                0.120                  NaN
#
#                                Mushrooms, King Oyster  Onion, yellow  \
#  Ergosta-5,7-dienol                            4.6430            NaN
#  Ergosta-7,22-dienol                           0.8038            NaN
# Alanine                                           NaN          0.021
# Alcohol, ethyl                                    NaN          0.000
# Amino acids                                    0.0000          0.000
# ...                                               ...            ...
# Vitamin K (Menaquinone-4)                         NaN            NaN
# Vitamin K (phylloquinone)                         NaN          0.400
# Vitamins and Other Components                  0.0000          0.000
# Water                                         88.1300         89.110
# Zinc, Zn                                       0.6254          0.170
#
#                                Orange juice  Parsnip  Potato, marble mix  \
#  Ergosta-5,7-dienol                     NaN      NaN                 NaN
#  Ergosta-7,22-dienol                    NaN      NaN                 NaN
# Alanine                                 NaN      NaN                 NaN
# Alcohol, ethyl                          NaN      NaN                 NaN
# Amino acids                             NaN     0.00                 NaN
# ...                                     ...      ...                 ...
# Vitamin K (Menaquinone-4)               NaN      NaN                 NaN
# Vitamin K (phylloquinone)               NaN    22.50                 NaN
# Vitamins and Other Components           NaN     0.00                0.00
# Water                                   NaN    79.53               83.29
# Zinc, Zn                                NaN     0.59                0.35
#
#                                Rhubarb  Potato, russet  Squash, Zucchini  \
#  Ergosta-5,7-dienol                NaN             NaN               NaN
#  Ergosta-7,22-dienol               NaN             NaN               NaN
# Alanine                            NaN            0.08             0.063
# Alcohol, ethyl                    0.00            0.00             0.000
# Amino acids                       0.00            0.00             0.000
# ...                                ...             ...               ...
# Vitamin K (Menaquinone-4)          NaN             NaN               NaN
# Vitamin K (phylloquinone)        29.30            2.00             4.300
# Vitamins and Other Components     0.00            0.00             0.000
# Water                            93.61           74.45            94.790
# Zinc, Zn                          0.10            0.35             0.320
#
#                                Marmite  Beef Liver
#  Ergosta-5,7-dienol                NaN         NaN
#  Ergosta-7,22-dienol               NaN         NaN
# Alanine                            NaN         NaN
# Alcohol, ethyl                    0.00        0.00
# Amino acids                        NaN         NaN
# ...                                ...         ...
# Vitamin K (Menaquinone-4)          NaN         NaN
# Vitamin K (phylloquinone)         0.00        3.90
# Vitamins and Other Components      NaN         NaN
# Water                            40.90       61.50
# Zinc, Zn                          4.19        5.19
#
# [161 rows x 20 columns]

# %% [markdown]
# ## Dietary Requirements

# %% [markdown]
# We&rsquo;ve figured out some foods we can buy, the nutritional content of
# those foods, and  the price of the foods.  Now we need to say
# something about nutritional requirements, and construct the vectors
# $b_{min}$ and $b_{max}$.   Our data for this is based
# on  US government recommendations available at
# [https://www.dietaryguidelines.gov/sites/default/files/2021-03/Dietary_Guidelines_for_Americans-2020-2025.pdf](https://www.dietaryguidelines.gov/sites/default/files/2021-03/Dietary_Guidelines_for_Americans-2020-2025.pdf)
#
# I&rsquo;ve put some of these data into a google spreadsheet at
# [https://docs.google.com/spreadsheets/d/1y95IsQ4HKspPW3HHDtH7QMtlDA66IUsCHJLutVL-MMc/](https://docs.google.com/spreadsheets/d/1y95IsQ4HKspPW3HHDtH7QMtlDA66IUsCHJLutVL-MMc/).
# Note that we&rsquo;ve tweaked the nutrient labels to match those in the FDC
# data.
#
# We&rsquo;ve broken down the requirements into three different tables.  The
# first is *minimum* quantities that we need to  satisfy.  For example,
# this table tells us that a 20 year-old female needs at least 46 grams
# of protein per day.

# %%
RDIs = read_sheets('https://docs.google.com/spreadsheets/d/1y95IsQ4HKspPW3HHDtH7QMtlDA66IUsCHJLutVL-MMc/')

bmin = RDIs['diet_minimums'].set_index('Nutrition')

# Drop string describing source
bmin = bmin.drop('Source',axis=1)

bmin
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
#                                  C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                          1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              14.0    16.8    19.6    22.4    25.2
# Folate, DFE                      150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                      700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference      130.0   130.0   130.0   130.0   130.0
# Iron, Fe                           7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     80.0   130.0   130.0   240.0   240.0
# Niacin                             6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                    460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                    3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                         0.5     0.6     0.6     0.9     0.9
# Thiamin                            0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                       0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                        0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)       6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)         30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                           3.0     5.0     5.0     8.0     8.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0

# %% [markdown]
# This next table specifies *maximum* quantities.  Our 20 year-old
# female shouldn&rsquo;t have more than 2300 milligrams of sodium per day.

# %%
bmax = RDIs['diet_maximums'].set_index('Nutrition')

# Drop string describing source
bmax = bmax.drop('Source',axis=1)

bmax
# Out:
#             C 1-3  F 4-8  M 4-8  F 9-13  M 9-13  F 14-18  M 14-18  F 19-30  \
# Nutrition
# Sodium, Na   1500   1900   1900    2200    2200     2300     2300     2300
# Energy       2500   2500   2500    2800    3000     3100     3100     3100
#
#             M 19-30  F 31-50  M 31-50  F 51+  M 51+
# Nutrition
# Sodium, Na     2300     2300     2300   2300   2300
# Energy         3100     3100     3100   3100   3100

# %% [markdown]
# ## Putting it together

# %% [markdown]
# Here we take the different pieces of the puzzle we&rsquo;ve developed and
# put them together in the form of a linear program we can solve.
# Recall that the mathematical problem we&rsquo;re trying to solve is
# $$
#     \min_x p'x
# $$
# such that
# $$
#      Ax \geq b
# $$

# %% [markdown]
# ### Objective function ($p$)

# %% [markdown]
# If we buy a bag of groceries with quantities given by $x$, the total
# cost of the bag of groceries is the inner product of prices and
# quantities.  Since we&rsquo;ve converted our units above, this gives us a
# vector of prices where quantities are all in 100 g or ml units.

# %%
p = Prices.apply(lambda x:x.magnitude).dropna()

# Compile list that we have both prices and nutritional info for; drop if either missing
use = p.index.intersection(D.columns)
p = p[use]

p
# Out:
# Bananas                   0.694456
# Beef Liver                2.107619
# Carrots, Organic          0.252429
# Cauliflower               0.372414
# Eggs, extra large         0.534226
# Endive, Red               1.097062
# Figs, black mission       1.097902
# Leeks, Organic            0.284396
# Lettuce, Little Gem       1.318364
# Marmite                   9.612155
# Milk, 2% fat              0.131822
# Mushrooms, King Oyster    2.645547
# Onion, yellow             0.085980
# Orange juice              0.474453
# Parsnip                   0.436515
# Potato, marble mix        0.570997
# Potato, russet            0.065698
# Rhubarb                   0.405651
# Squash, Zucchini          0.328489
# Name: FDC Price, dtype: float64

# %% [markdown]
# ### Nutrient Mapping Matrix ($A$)

# %% [markdown]
# The matrix $A$ maps a bag of groceries $x$ into nutrients, but we
# don&rsquo;t need to keep track of nutrients for which we don&rsquo;t have
# contraints.

# %%
# Drop nutritional information for foods we don't know the price of,
# and replace missing nutrients with zeros.
Aall = D[p.index].fillna(0)

# Drop rows of A that we don't have constraints for.
Amin = Aall.loc[bmin.index]

Amax = Aall.loc[bmax.index]

# Maximum requirements involve multiplying constraint by -1 to make <=.
A = pd.concat([Amin,-Amax])

A
# Out:
#                                 Bananas  Beef Liver  Carrots, Organic  \
# Nutrition
# Energy                          371.000     174.000           173.000
# Protein                           1.090      26.300             0.930
# Fiber, total dietary              2.600       0.000             2.800
# Folate, DFE                      20.000     258.000            19.000
# Calcium, Ca                       5.000       6.000            33.000
# Carbohydrate, by difference      22.840       5.120             9.580
# Iron, Fe                          0.260       6.120             0.300
# Magnesium, Mg                    27.000      22.000            12.000
# Niacin                            0.665      17.300             0.983
# Phosphorus, P                    22.000     481.000            35.000
# Potassium, K                    358.000     348.000           320.000
# Riboflavin                        0.073       3.400             0.058
# Thiamin                           0.031       0.176             0.066
# Vitamin A, RAE                    3.000    7680.000           835.000
# Vitamin B-12                      0.000      82.500             0.000
# Vitamin B-6                       0.367       1.020             0.138
# Vitamin C, total ascorbic acid    8.700       0.700             5.900
# Vitamin E (alpha-tocopherol)      0.100       0.460             0.660
# Vitamin K (phylloquinone)         0.500       3.900            13.200
# Zinc, Zn                          0.150       5.190             0.240
# Sodium, Na                       -1.000    -384.000           -69.000
# Energy                         -371.000    -174.000          -173.000
#
#                                 Cauliflower  Eggs, extra large  Endive, Red  \
# Nutrition
# Energy                              104.000            231.000       71.000
# Protein                               1.920             10.700        1.250
# Fiber, total dietary                  2.000              0.000        3.100
# Folate, DFE                          57.000              0.000      142.000
# Calcium, Ca                          22.000              0.000       52.000
# Carbohydrate, by difference           4.970              2.360        3.350
# Iron, Fe                              0.420              0.000        0.830
# Magnesium, Mg                        15.000              0.000       15.000
# Niacin                                0.507              0.000        0.400
# Phosphorus, P                        44.000              0.000       28.000
# Potassium, K                        299.000              0.000      314.000
# Riboflavin                            0.060              0.391        0.075
# Thiamin                               0.050              0.000        0.080
# Vitamin A, RAE                        0.000              0.000      108.000
# Vitamin B-12                          0.000              0.000        0.000
# Vitamin B-6                           0.184              0.000        0.020
# Vitamin C, total ascorbic acid       48.200              0.000        6.500
# Vitamin E (alpha-tocopherol)          0.080              0.000        0.440
# Vitamin K (phylloquinone)            15.500              0.000      231.000
# Zinc, Zn                              0.270              0.000        0.790
# Sodium, Na                          -30.000             -0.000      -22.000
# Energy                             -104.000           -231.000      -71.000
#
#                                 Figs, black mission  Leeks, Organic  \
# Nutrition
# Energy                                        300.0         255.000
# Protein                                         2.5           1.500
# Fiber, total dietary                           12.5           1.800
# Folate, DFE                                     0.0          64.000
# Calcium, Ca                                   150.0          59.000
# Carbohydrate, by difference                    72.5          14.150
# Iron, Fe                                        3.6           2.100
# Magnesium, Mg                                   0.0          28.000
# Niacin                                          0.0           0.400
# Phosphorus, P                                   0.0          35.000
# Potassium, K                                    0.0         180.000
# Riboflavin                                      0.0           0.030
# Thiamin                                         0.0           0.060
# Vitamin A, RAE                                  0.0          83.000
# Vitamin B-12                                    0.0           0.000
# Vitamin B-6                                     0.0           0.233
# Vitamin C, total ascorbic acid                  0.0          12.000
# Vitamin E (alpha-tocopherol)                    0.0           0.920
# Vitamin K (phylloquinone)                       0.0          47.000
# Zinc, Zn                                        0.0           0.120
# Sodium, Na                                    -12.0         -20.000
# Energy                                       -300.0        -255.000
#
#                                 Lettuce, Little Gem  Marmite  Milk, 2% fat  \
# Nutrition
# Energy                                        24.00   185.00         54.00
# Protein                                        1.18    23.90          3.33
# Fiber, total dietary                           2.40     6.50          0.00
# Folate, DFE                                    0.00  5880.00          0.00
# Calcium, Ca                                   35.00    67.00        129.00
# Carbohydrate, by difference                    3.53    20.40          5.00
# Iron, Fe                                       0.94     4.04          0.00
# Magnesium, Mg                                  0.00   180.00          0.00
# Niacin                                         0.00   128.00          0.00
# Phosphorus, P                                  0.00   104.00          0.00
# Potassium, K                                 247.00  2100.00        162.00
# Riboflavin                                     0.00    17.50          0.00
# Thiamin                                        0.00    23.40          0.00
# Vitamin A, RAE                                 0.00     0.00          0.00
# Vitamin B-12                                   0.00     0.50          0.00
# Vitamin B-6                                    0.00     0.00          0.00
# Vitamin C, total ascorbic acid                 0.00     0.00          0.00
# Vitamin E (alpha-tocopherol)                   0.00     0.00          0.00
# Vitamin K (phylloquinone)                      0.00     0.00          0.00
# Zinc, Zn                                       0.00     4.19          0.00
# Sodium, Na                                    -6.00 -3380.00        -40.00
# Energy                                       -24.00  -185.00        -54.00
#
#                                 Mushrooms, King Oyster  Onion, yellow  \
# Nutrition
# Energy                                        0.000000        166.000
# Protein                                       2.406250          1.100
# Fiber, total dietary                          3.009000          1.700
# Folate, DFE                                   0.000000         19.000
# Calcium, Ca                                   0.000000         23.000
# Carbohydrate, by difference                   8.500650          9.340
# Iron, Fe                                      0.338100          0.210
# Magnesium, Mg                                13.510000         10.000
# Niacin                                        6.451000          0.116
# Phosphorus, P                                89.860000         29.000
# Potassium, K                                294.500000        146.000
# Riboflavin                                    0.243800          0.027
# Thiamin                                       0.006375          0.046
# Vitamin A, RAE                                0.000000          0.000
# Vitamin B-12                                  0.000000          0.000
# Vitamin B-6                                   0.118800          0.120
# Vitamin C, total ascorbic acid                0.000000          7.400
# Vitamin E (alpha-tocopherol)                  0.000000          0.020
# Vitamin K (phylloquinone)                     0.000000          0.400
# Zinc, Zn                                      0.625400          0.170
# Sodium, Na                                   -0.771300         -4.000
# Energy                                       -0.000000       -166.000
#
#                                 Orange juice  Parsnip  Potato, marble mix  \
# Nutrition
# Energy                                 46.00   314.00             243.000
# Protein                                 0.83     1.20               2.570
# Fiber, total dietary                    0.00     4.90               2.500
# Folate, DFE                             0.00    67.00              17.000
# Calcium, Ca                             8.00    36.00              30.000
# Carbohydrate, by difference            10.83    17.99              12.440
# Iron, Fe                                0.00     0.59               3.240
# Magnesium, Mg                          10.00    29.00              23.000
# Niacin                                  0.00     0.70               1.033
# Phosphorus, P                           8.00    71.00              38.000
# Potassium, K                          188.00   375.00             413.000
# Riboflavin                              0.00     0.05               0.038
# Thiamin                                 0.00     0.09               0.021
# Vitamin A, RAE                          0.00     0.00               0.000
# Vitamin B-12                            0.00     0.00               0.000
# Vitamin B-6                             0.00     0.09               0.239
# Vitamin C, total ascorbic acid         30.00    17.00              11.400
# Vitamin E (alpha-tocopherol)            0.00     1.49               0.000
# Vitamin K (phylloquinone)               0.00    22.50               0.000
# Zinc, Zn                                0.00     0.59               0.350
# Sodium, Na                             -0.00   -10.00             -10.000
# Energy                                -46.00  -314.00            -243.000
#
#                                 Potato, russet  Rhubarb  Squash, Zucchini
# Nutrition
# Energy                                 397.000   88.000            70.000
# Protein                                  2.630    0.900             1.210
# Fiber, total dietary                     2.300    1.800             1.000
# Folate, DFE                             26.000    7.000            24.000
# Calcium, Ca                             18.000   86.000            16.000
# Carbohydrate, by difference             21.440    4.540             3.110
# Iron, Fe                                 1.070    0.220             0.370
# Magnesium, Mg                           30.000   12.000            18.000
# Niacin                                   1.348    0.300             0.451
# Phosphorus, P                           71.000   14.000            38.000
# Potassium, K                           550.000  288.000           261.000
# Riboflavin                               0.048    0.030             0.094
# Thiamin                                  0.067    0.020             0.045
# Vitamin A, RAE                           1.000    5.000            10.000
# Vitamin B-12                             0.000    0.000             0.000
# Vitamin B-6                              0.354    0.024             0.163
# Vitamin C, total ascorbic acid           8.300    8.000            17.900
# Vitamin E (alpha-tocopherol)             0.070    0.270             0.120
# Vitamin K (phylloquinone)                2.000   29.300             4.300
# Zinc, Zn                                 0.350    0.100             0.320
# Sodium, Na                             -14.000   -4.000            -8.000
# Energy                                -397.000  -88.000           -70.000

# %% [markdown]
# ### Constraint vector ($b$)

# %% [markdown]
# Finally, the right hand side vector $b$ in the expression
# $$
#     Ax\geq b
# $$

# %%
b = pd.concat([bmin,-bmax]) # Note sign change for max constraints

b
# Out:
#                                  C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                          1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              14.0    16.8    19.6    22.4    25.2
# Folate, DFE                      150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                      700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference      130.0   130.0   130.0   130.0   130.0
# Iron, Fe                           7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     80.0   130.0   130.0   240.0   240.0
# Niacin                             6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                    460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                    3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                         0.5     0.6     0.6     0.9     0.9
# Thiamin                            0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                       0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                        0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)       6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)         30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                           3.0     5.0     5.0     8.0     8.0
# Sodium, Na                     -1500.0 -1900.0 -1900.0 -2200.0 -2200.0
# Energy                         -2500.0 -2500.0 -2500.0 -2800.0 -3000.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
# Sodium, Na                      -2300.0  -2300.0  -2300.0  -2300.0  -2300.0
# Energy                          -3100.0  -3100.0  -3100.0  -3100.0  -3100.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0
# Sodium, Na                      -2300.0 -2300.0 -2300.0
# Energy                          -3100.0 -3100.0 -3100.0

# %% [markdown]
# ## Solving the problem

# %% [markdown]
# First, we find a solution to the problem

# %%
from  scipy.optimize import linprog as lp
import numpy as np

tol = 1e-6 # Numbers in solution smaller than this (in absolute value) treated as zeros

## Choose sex/age group!
group = "F 19-30"

# Now solve problem!  (Note that the linear program solver we'll use assumes
# "less-than-or-equal" constraints.  We can switch back and forth by
# multiplying $A$ and $b$ by $-1$.)

result = lp(p, -A, -b[group], method='interior-point')

result
# Out:
#      con: array([], dtype=float64)
#      fun: 16.176838591891055
#  message: 'Optimization terminated successfully.'
#      nit: 17
#    slack: array([1.10000000e+03, 1.23552550e-06, 3.69093436e+01, 1.73791615e+03,
#        9.86738087e-07, 3.91375672e+01, 5.34154303e-08, 6.35317388e+01,
#        7.73465093e+00, 4.24990920e+02, 1.58867014e+03, 2.54496330e+00,
#        4.76233717e-01, 6.16829950e+03, 5.88487550e+01, 3.55856729e-01,
#        1.08918442e+02, 1.65220726e-09, 2.49339386e+03, 7.97772995e+00,
#        1.65156540e+03, 5.35483196e-07])
#   status: 0
#  success: True
#        x: array([1.08226823e-09, 7.42409151e-01, 2.89021370e-08, 5.48190204e-09,
#        2.60802766e-09, 1.04470862e+01, 1.16512251e-09, 4.61588947e-01,
#        6.95522590e-09, 1.37503071e-09, 1.49008007e+00, 3.56227968e-09,
#        2.84478481e-09, 7.00398516e-09, 6.46786038e+00, 1.71105111e-09,
#        1.65015076e-09, 1.05362992e-07, 9.10577153e-09])

# %% [markdown]
# Let&rsquo;s interpret this.  Start with the cost of the solution:

# %%
print(f"Cost of diet for {group} is ${result.fun:.2f} per day.")
# Out:
# Cost of diet for F 19-30 is $16.18 per day.

# %% [markdown]
# Next, what is it we&rsquo;re actually eating?

# %%
# Put back into nice series
diet = pd.Series(result.x,index=p.index)

print("\nYou'll be eating (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.
# Out:
# You'll be eating (in 100s of grams or milliliters):
# Beef Liver         0.742409
# Endive, Red       10.447086
# Leeks, Organic     0.461589
# Milk, 2% fat       1.490080
# Parsnip            6.467860
# dtype: float64

# %% [markdown]
# Given this diet, what are nutritional outcomes?

# %%
tab = pd.DataFrame({"Outcome":np.abs(A).dot(diet),"Recommendation":np.abs(b[group])})
print("\nWith the following nutritional outcomes of interest:")
tab
# Out:
# With the following nutritional outcomes of interest:
#                                     Outcome  Recommendation
# Nutrition
# Energy                          3099.999999          2000.0
# Protein                           46.000001            46.0
# Fiber, total dietary              64.909344            28.0
# Folate, DFE                     2137.916154           400.0
# Calcium, Ca                     1000.000001          1000.0
# Carbohydrate, by difference      169.137567           130.0
# Iron, Fe                          18.000000            18.0
# Magnesium, Mg                    373.531739           310.0
# Niacin                            21.734651            14.0
# Phosphorus, P                   1124.990920           700.0
# Potassium, K                    6288.670140          4700.0
# Riboflavin                         3.644963             1.1
# Thiamin                            1.576234             1.1
# Vitamin A, RAE                  6868.299502           700.0
# Vitamin B-12                      61.248755             2.4
# Vitamin B-6                        1.655857             1.3
# Vitamin C, total ascorbic acid   183.918442            75.0
# Vitamin E (alpha-tocopherol)      15.000000            15.0
# Vitamin K (phylloquinone)       2583.393857            90.0
# Zinc, Zn                          15.977730             8.0
# Sodium, Na                       648.434604          2300.0
# Energy                          3099.999999          3100.0

# %% [markdown]
# Finally, what are the constraints that bind?  Finding a less expensive
# diet might involve finding less expensive sources for these particular nutrients.

# %%
print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol].index.tolist())
# Out:
# Constraining nutrients are:
# ['Calcium, Ca', 'Iron, Fe', 'Vitamin E (alpha-tocopherol)', 'Energy']
